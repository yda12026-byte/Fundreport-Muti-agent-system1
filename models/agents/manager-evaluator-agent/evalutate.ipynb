# %% [markdown]
# 在 MAUT 中，总效用函数最常见的形式是加法模型（Additive Model）：$$U(x) = \sum_{i=1}^{n} w_i \cdot u_i(x_i)$$其中：$x_i$ 是基金在第 $i$ 个维度（如经理年限、夏普比率等）的具体表现值。$u_i(x_i)$ 是单属性效用函数（SAUF），负责将原始数值映射到 $[0, 1]$ 之间。$w_i$ 是权重，反映用户对该维度的重视程度，通常要求 $\sum w_i = 1$。
